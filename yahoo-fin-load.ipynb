# %%
import yfinance as yf

import pandas as pd
from yahoo_fin_api import load_df

# %% [markdown]
# ## Download and Set Mean

# %%
df =  yf.download(
    tickers="KRWUSD=X", 
    start="1990-02-24", 
    end="2023-02-24", 
    interval="1d"
    )
# including Dot-com Bubble (1995-2001), Great Recession(2008-2011), Great Lockdown(2020-2023)

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2003-12-01  0.000835  0.000837  0.000831  0.000834   0.000834       0
# 2003-12-02  0.000835  0.000843  0.000834  0.000837   0.000837       0
# 2003-12-03  0.000837  0.000839  0.000834  0.000839   0.000839       0
# 2003-12-04  0.000839  0.000851  0.000835  0.000840   0.000840       0
# 2003-12-05  0.000841  0.000848  0.000838  0.000844   0.000844       0

# %%
df['Mean'] = df[['Open', 'High', 'Low', 'Close']].mean(axis=1)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume  \
# Date
# 2003-12-01  0.000835  0.000837  0.000831  0.000834   0.000834       0
# 2003-12-02  0.000835  0.000843  0.000834  0.000837   0.000837       0
# 2003-12-03  0.000837  0.000839  0.000834  0.000839   0.000839       0
# 2003-12-04  0.000839  0.000851  0.000835  0.000840   0.000840       0
# 2003-12-05  0.000841  0.000848  0.000838  0.000844   0.000844       0
#
#                 Mean
# Date
# 2003-12-01  0.000834
# 2003-12-02  0.000837
# 2003-12-03  0.000837
# 2003-12-04  0.000841
# 2003-12-05  0.000843

# %%
df.to_csv('data/krw-usd.csv')

# %%
df = load_df('data/krw-usd.csv')
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume  \
# Date
# 2003-12-01  0.000835  0.000837  0.000831  0.000834   0.000834       0
# 2003-12-02  0.000835  0.000843  0.000834  0.000837   0.000837       0
# 2003-12-03  0.000837  0.000839  0.000834  0.000839   0.000839       0
# 2003-12-04  0.000839  0.000851  0.000835  0.000840   0.000840       0
# 2003-12-05  0.000841  0.000848  0.000838  0.000844   0.000844       0
#
#                 Mean
# Date
# 2003-12-01  0.000834
# 2003-12-02  0.000837
# 2003-12-03  0.000837
# 2003-12-04  0.000841
# 2003-12-05  0.000843

# %% [markdown]
# ## Minor Viz

# %%
fig = df.plot.line(y='Mean').get_figure()
fig.set_size_inches(18, 10)
